# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>
#
# # Simple APIs
# ## Random User and Fruitvice API Examples
#
#
# Estimated time needed: **25** minutes
#
# ## Objectives
#
# After completing this lab you will be able to:
#
# *   Load and use RandomUser API, using `RandomUser()` Python library
# *   Load and use Fruitvice API, using `requests` Python library

# %% [markdown]
# The purpose of this notebook is to provide more examples on how to use simple APIs. As you have already learned from previous videos and notebooks, API stands for Application Programming Interface and is a software intermediary that allows two applications to talk to each other.
#
# The advantages of using APIs:
#  *   **Automation**. Less human effort is required and workflows can be easily updated to become faster and more
#      productive.
#  *   **Efficiency**. It allows to use the capabilities of one of the already developed APIs than to try to
#      independently implement some functionality from scratch.
#
# The disadvantage of using APIs:
#  *   **Secirity**. If the API is poorly integrated, it means it will be vulnerable to attacks, resulting in data
#      breeches or losses having financial or reputation implications.
#
# One of the applications we will use in this notebook is Random User Generator. RandomUser is an open-source, free API providing developers with randomly generated users to be used as placeholders for testing purposes. This makes the tool similar to Lorem Ipsum, but is a placeholder for people instead of text. The API can return multiple results, as well as specify generated user details such as gender, email, image, username, address, title, first and last name, and more. More information on [RandomUser](https://randomuser.me/documentation?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork1005-2022-01-01#intro) can be found here.
#
# Another example of simple API we will use in this notebook is Fruitvice application. The Fruitvice API webservice which provides data for all kinds of fruit! You can use Fruityvice to find out interesting information about fruit and educate yourself. The webservice is completely free to use and contribute to.

# %% [markdown]
# ## Example 1: RandomUser API
# Bellow are Get Methods parameters that we can generate. For more information on the parameters, please visit this [documentation](https://randomuser.me/documentation?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork1005-2022-01-01) page.

# %% [markdown]
# ## **Get Methods**
#
# - get_cell()
# - get_city()
# - get_dob()
# - get_email()
# - get_first_name()
# - get_full_name()
# - get_gender()
# - get_id()
# - get_id_number()
# - get_id_type()
# - get_info()
# - get_last_name()
# - get_login_md5()
# - get_login_salt()
# - get_login_sha1()
# - get_login_sha256()
# - get_nat()
# - get_password()
# - get_phone()
# - get_picture()
# - get_postcode()
# - get_registered()
# - get_state()
# - get_street()
# - get_username()
# - get_zipcode()

# %% [markdown]
# To start using the API you can install the `randomuser` library running the `pip install` command.

# %%
# !pip install randomuser
# Out:
# Requirement already satisfied: randomuser in c:\programdata\anaconda3\lib\site-packages (1.6)

# %% [markdown]
# Then, we will load the necessary libraries.

# %%
from randomuser import RandomUser
import pandas as pd

# %% [markdown]
# First, we will create a random user object, r.

# %%
r = RandomUser()

# %% [markdown]
# Then, using `generate_users()` function, we get a list of random 10 users.

# %%
some_list = r.generate_users(10)

# %%
some_list
# Out:
# [<randomuser.RandomUser at 0x1fda69ca460>,
#  <randomuser.RandomUser at 0x1fda69ca1f0>,
#  <randomuser.RandomUser at 0x1fda69ca160>,
#  <randomuser.RandomUser at 0x1fdab37da00>,
#  <randomuser.RandomUser at 0x1fdab37d970>,
#  <randomuser.RandomUser at 0x1fdab37dd00>,
#  <randomuser.RandomUser at 0x1fdad788310>,
#  <randomuser.RandomUser at 0x1fdad7883d0>,
#  <randomuser.RandomUser at 0x1fdad7882e0>,
#  <randomuser.RandomUser at 0x1fdad788190>]

# %% [markdown]
# The **"Get Methods"** functions mentioned at the beginning of this notebook, can generate the required parameters to construct a dataset. For example, to get full name, we call `get_full_name()` function.

# %%
name = r.get_full_name()

# %% [markdown]
# Let's say we only need 10 users with full names and their email addresses. We can write a "for-loop" to print these 10 users.

# %%
for user in some_list:
    print (user.get_full_name()," ",user.get_email())
# Out:
# Philip Thomsen   philip.thomsen@example.com
# George Holt   george.holt@example.com
# Simen Kjølberg   simen.kjolberg@example.com
# Oğuzhan Erbay   oguzhan.erbay@example.com
# Vicente Gil   vicente.gil@example.com
# Latife Balcı   latife.balci@example.com
# Marianne Mitchell   marianne.mitchell@example.com
# Sina Reh   sina.reh@example.com
# تینا پارسا   tyn.prs@example.com
# Solène Rousseau   solene.rousseau@example.com

# %% [markdown]
# ## Exercise 1
# In this Exercise, generate photos of the random 5 users.

# %%
## Write your code here
for user in some_list:
    print (user.get_picture())
# Out:
# https://randomuser.me/api/portraits/men/41.jpg
# https://randomuser.me/api/portraits/men/12.jpg
# https://randomuser.me/api/portraits/men/52.jpg
# https://randomuser.me/api/portraits/men/36.jpg
# https://randomuser.me/api/portraits/men/20.jpg
# https://randomuser.me/api/portraits/women/62.jpg
# https://randomuser.me/api/portraits/women/4.jpg
# https://randomuser.me/api/portraits/women/33.jpg
# https://randomuser.me/api/portraits/women/79.jpg
# https://randomuser.me/api/portraits/women/45.jpg

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# for user in some_list:
#     print (user.get_picture())
# ```
#
# </details>

# %% [markdown]
# To generate a table with information about the users, we can write a function containing all desirable parameters. For example, name, gender, city, etc. The parameters will depend on the requirements of the test to be performed. We call the Get Methods, listed at the beginning of this notebook. Then, we return pandas dataframe with the users.

# %%
def get_users():
    users =[]
     
    for user in RandomUser.generate_users(10):
        users.append({"Name":user.get_full_name(),"Gender":user.get_gender(),"City":user.get_city(),"State":user.get_state(),"Email":user.get_email(), "DOB":user.get_dob(),"Picture":user.get_picture()})
      
    return pd.DataFrame(users)

# %%
get_users()
# Out:
#                Name  Gender      City          State  \
# 0      Simon French    male  Glenwood        Nunavut
# 1     Vernon Fields    male     Ennis  Massachusetts
# 2        Mila Melby  female   Foldrøy       Buskerud
# 3      Layla Wilson  female    Timaru     Canterbury
# 4  Alfred Jørgensen    male    Haslev       Sjælland
# 5     Alvin Mendoza    male   Belfast          Clwyd
# 6   Charlie Hopland    male    Hovden       Rogaland
# 7     میلاد محمدخان    male       آمل   خراسان شمالی
# 8    Zeynep Lacroix  female  Treyvaux      Neuchâtel
# 9        Eeli Koski    male  Naantali        Lapland
#
#                           Email                       DOB  \
# 0      simon.french@example.com  1966-03-24T05:19:10.345Z
# 1     vernon.fields@example.com  1990-08-25T15:13:40.309Z
# 2        mila.melby@example.com  1946-05-13T22:11:18.652Z
# 3      layla.wilson@example.com  1945-05-05T07:07:26.250Z
# 4  alfred.jorgensen@example.com  1988-04-27T08:59:38.912Z
# 5     alvin.mendoza@example.com  1969-05-13T17:48:12.865Z
# 6   charlie.hopland@example.com  1950-08-31T21:42:38.032Z
# 7      myld.mhmdkhn@example.com  1953-08-23T01:24:49.998Z
# 8    zeynep.lacroix@example.com  1953-07-16T13:21:38.412Z
# 9        eeli.koski@example.com  1967-12-29T04:03:23.769Z
#
#                                             Picture
# 0    https://randomuser.me/api/portraits/men/94.jpg
# 1    https://randomuser.me/api/portraits/men/95.jpg
# 2  https://randomuser.me/api/portraits/women/64.jpg
# 3  https://randomuser.me/api/portraits/women/84.jpg
# 4    https://randomuser.me/api/portraits/men/24.jpg
# 5    https://randomuser.me/api/portraits/men/93.jpg
# 6    https://randomuser.me/api/portraits/men/12.jpg
# 7    https://randomuser.me/api/portraits/men/89.jpg
# 8  https://randomuser.me/api/portraits/women/42.jpg
# 9    https://randomuser.me/api/portraits/men/47.jpg

# %%
df1 = pd.DataFrame(get_users())

# %% [markdown]
# Now we have a *pandas* dataframe that can be used for any testing purposes that the tester might have.

# %% [markdown]
# ## Example 2: Fruitvice API
#
# Another, more common way to use APIs, is through `requests` library. The next lab, Requests and HTTP, will contain more information about requests.
#
# We will start by importing all required libraries.

# %%
import requests
import json

# %% [markdown]
# We will obtain the [fruitvice](https://www.fruityvice.com/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork1005-2022-01-01) API data using `requests.get("url")` function. The data is in a json format.

# %%
data = requests.get("https://www.fruityvice.com/api/fruit/all")

# %% [markdown]
# We will retrieve results using `json.loads()` function.

# %%
results = json.loads(data.text)

# %% [markdown]
# We will convert our json data into *pandas* data frame.

# %%
pd.DataFrame(results)
# Out:
#            genus          name  id           family             order  \
# 0          Malus         Apple   6         Rosaceae           Rosales
# 1         Prunus       Apricot  35         Rosaceae           Rosales
# 2         Persea       Avocado  84        Lauraceae          Laurales
# 3           Musa        Banana   1         Musaceae      Zingiberales
# 4          Rubus    Blackberry  64         Rosaceae           Rosales
# 5       Fragaria     Blueberry  33         Rosaceae           Rosales
# 6         Prunus        Cherry   9         Rosaceae           Rosales
# 7      Vaccinium     Cranberry  87        Ericaceae          Ericales
# 8   Selenicereus   Dragonfruit  80        Cactaceae    Caryophyllales
# 9          Durio        Durian  60        Malvaceae          Malvales
# 10    Sellowiana        Feijoa  76        Myrtaceae        Myrtoideae
# 11         Ficus           Fig  68         Moraceae           Rosales
# 12         Ribes    Gooseberry  69  Grossulariaceae      Saxifragales
# 13         Vitis         Grape  81         Vitaceae           Vitales
# 14         Malus    GreenApple  72         Rosaceae           Rosales
# 15       Psidium         Guava  37        Myrtaceae          Myrtales
# 16       Apteryx          Kiwi  66    Actinidiaceae  Struthioniformes
# 17     Actinidia     Kiwifruit  85    Actinidiaceae          Ericales
# 18        Citrus         Lemon  26         Rutaceae        Sapindales
# 19        Citrus          Lime  44         Rutaceae        Sapindales
# 20     Vaccinium   Lingonberry  65        Ericaceae          Ericales
# 21        Litchi        Lychee  67      Sapindaceae        Sapindales
# 22     Mangifera         Mango  27    Anacardiaceae        Sapindales
# 23       Cucumis         Melon  41    Cucurbitaceae     Cucurbitaceae
# 24         Morus         Morus  82         Moraceae           Rosales
# 25        Citrus        Orange   2         Rutaceae        Sapindales
# 26        Carica        Papaya  42       Caricaceae         Caricacea
# 27    Passiflora  Passionfruit  70   Passifloraceae      Malpighiales
# 28        Prunus         Peach  86         Rosaceae           Rosales
# 29         Pyrus          Pear   4         Rosaceae           Rosales
# 30     Diospyros     Persimmon  52        Ebenaceae           Rosales
# 31        Ananas     Pineapple  10     Bromeliaceae            Poales
# 32     Cactaceae      Pitahaya  78        Cactaceae    Caryophyllales
# 33        Prunus          Plum  71         Rosaceae           Rosales
# 34        Punica   Pomegranate  79       Lythraceae          Myrtales
# 35         Rubus     Raspberry  23         Rosaceae           Rosales
# 36      Fragaria    Strawberry   3         Rosaceae           Rosales
# 37        Citrus     Tangerine  77         Rutaceae        Sapindales
# 38       Solanum        Tomato   5       Solanaceae         Solanales
# 39     Citrullus    Watermelon  25    Cucurbitaceae      Cucurbitales
#
#                                            nutritions
# 0   {'carbohydrates': 11.4, 'protein': 0.3, 'fat':...
# 1   {'carbohydrates': 3.9, 'protein': 0.5, 'fat': ...
# 2   {'carbohydrates': 8.53, 'protein': 2, 'fat': 1...
# 3   {'carbohydrates': 22, 'protein': 1, 'fat': 0.2...
# 4   {'carbohydrates': 9, 'protein': 1.3, 'fat': 0....
# 5   {'carbohydrates': 5.5, 'protein': 0, 'fat': 0....
# 6   {'carbohydrates': 12, 'protein': 1, 'fat': 0.3...
# 7   {'carbohydrates': 12.2, 'protein': 0.4, 'fat':...
# 8   {'carbohydrates': 9, 'protein': 9, 'fat': 1.5,...
# 9   {'carbohydrates': 27.1, 'protein': 1.5, 'fat':...
# 10  {'carbohydrates': 8, 'protein': 0.6, 'fat': 0....
# 11  {'carbohydrates': 19, 'protein': 0.8, 'fat': 0...
# 12  {'carbohydrates': 10, 'protein': 0.9, 'fat': 0...
# 13  {'carbohydrates': 18.1, 'protein': 0.72, 'fat'...
# 14  {'carbohydrates': 3.1, 'protein': 0.4, 'fat': ...
# 15  {'carbohydrates': 14, 'protein': 2.6, 'fat': 1...
# 16  {'carbohydrates': 15, 'protein': 1.1, 'fat': 0...
# 17  {'carbohydrates': 14.6, 'protein': 1.14, 'fat'...
# 18  {'carbohydrates': 9, 'protein': 1.1, 'fat': 0....
# 19  {'carbohydrates': 8.4, 'protein': 0.3, 'fat': ...
# 20  {'carbohydrates': 11.3, 'protein': 0.75, 'fat'...
# 21  {'carbohydrates': 17, 'protein': 0.8, 'fat': 0...
# 22  {'carbohydrates': 15, 'protein': 0.82, 'fat': ...
# 23  {'carbohydrates': 8, 'protein': 0, 'fat': 0, '...
# 24  {'carbohydrates': 9.8, 'protein': 1.44, 'fat':...
# 25  {'carbohydrates': 8.3, 'protein': 1, 'fat': 0....
# 26  {'carbohydrates': 11, 'protein': 0, 'fat': 0.4...
# 27  {'carbohydrates': 22.4, 'protein': 2.2, 'fat':...
# 28  {'carbohydrates': 9.5, 'protein': 0.9, 'fat': ...
# 29  {'carbohydrates': 15, 'protein': 0.4, 'fat': 0...
# 30  {'carbohydrates': 18, 'protein': 0, 'fat': 0, ...
# 31  {'carbohydrates': 13.12, 'protein': 0.54, 'fat...
# 32  {'carbohydrates': 7, 'protein': 1, 'fat': 0.4,...
# 33  {'carbohydrates': 11.4, 'protein': 0.7, 'fat':...
# 34  {'carbohydrates': 18.7, 'protein': 1.7, 'fat':...
# 35  {'carbohydrates': 12, 'protein': 1.2, 'fat': 0...
# 36  {'carbohydrates': 5.5, 'protein': 0.8, 'fat': ...
# 37  {'carbohydrates': 8.3, 'protein': 0, 'fat': 0....
# 38  {'carbohydrates': 3.9, 'protein': 0.9, 'fat': ...
# 39  {'carbohydrates': 8, 'protein': 0.6, 'fat': 0....

# %% [markdown]
# The result is in a nested json format. The 'nutrition' column contains multiple subcolumns, so the data needs to be 'flattened' or normalized.

# %%
df2 = pd.json_normalize(results)

# %%
df2
# Out:
#            genus          name  id           family             order  \
# 0          Malus         Apple   6         Rosaceae           Rosales
# 1         Prunus       Apricot  35         Rosaceae           Rosales
# 2         Persea       Avocado  84        Lauraceae          Laurales
# 3           Musa        Banana   1         Musaceae      Zingiberales
# 4          Rubus    Blackberry  64         Rosaceae           Rosales
# 5       Fragaria     Blueberry  33         Rosaceae           Rosales
# 6         Prunus        Cherry   9         Rosaceae           Rosales
# 7      Vaccinium     Cranberry  87        Ericaceae          Ericales
# 8   Selenicereus   Dragonfruit  80        Cactaceae    Caryophyllales
# 9          Durio        Durian  60        Malvaceae          Malvales
# 10    Sellowiana        Feijoa  76        Myrtaceae        Myrtoideae
# 11         Ficus           Fig  68         Moraceae           Rosales
# 12         Ribes    Gooseberry  69  Grossulariaceae      Saxifragales
# 13         Vitis         Grape  81         Vitaceae           Vitales
# 14         Malus    GreenApple  72         Rosaceae           Rosales
# 15       Psidium         Guava  37        Myrtaceae          Myrtales
# 16       Apteryx          Kiwi  66    Actinidiaceae  Struthioniformes
# 17     Actinidia     Kiwifruit  85    Actinidiaceae          Ericales
# 18        Citrus         Lemon  26         Rutaceae        Sapindales
# 19        Citrus          Lime  44         Rutaceae        Sapindales
# 20     Vaccinium   Lingonberry  65        Ericaceae          Ericales
# 21        Litchi        Lychee  67      Sapindaceae        Sapindales
# 22     Mangifera         Mango  27    Anacardiaceae        Sapindales
# 23       Cucumis         Melon  41    Cucurbitaceae     Cucurbitaceae
# 24         Morus         Morus  82         Moraceae           Rosales
# 25        Citrus        Orange   2         Rutaceae        Sapindales
# 26        Carica        Papaya  42       Caricaceae         Caricacea
# 27    Passiflora  Passionfruit  70   Passifloraceae      Malpighiales
# 28        Prunus         Peach  86         Rosaceae           Rosales
# 29         Pyrus          Pear   4         Rosaceae           Rosales
# 30     Diospyros     Persimmon  52        Ebenaceae           Rosales
# 31        Ananas     Pineapple  10     Bromeliaceae            Poales
# 32     Cactaceae      Pitahaya  78        Cactaceae    Caryophyllales
# 33        Prunus          Plum  71         Rosaceae           Rosales
# 34        Punica   Pomegranate  79       Lythraceae          Myrtales
# 35         Rubus     Raspberry  23         Rosaceae           Rosales
# 36      Fragaria    Strawberry   3         Rosaceae           Rosales
# 37        Citrus     Tangerine  77         Rutaceae        Sapindales
# 38       Solanum        Tomato   5       Solanaceae         Solanales
# 39     Citrullus    Watermelon  25    Cucurbitaceae      Cucurbitales
#
#     nutritions.carbohydrates  nutritions.protein  nutritions.fat  \
# 0                      11.40                0.30            0.40
# 1                       3.90                0.50            0.10
# 2                       8.53                2.00           14.66
# 3                      22.00                1.00            0.20
# 4                       9.00                1.30            0.40
# 5                       5.50                0.00            0.40
# 6                      12.00                1.00            0.30
# 7                      12.20                0.40            0.10
# 8                       9.00                9.00            1.50
# 9                      27.10                1.50            5.30
# 10                      8.00                0.60            0.40
# 11                     19.00                0.80            0.30
# 12                     10.00                0.90            0.60
# 13                     18.10                0.72            0.16
# 14                      3.10                0.40            0.10
# 15                     14.00                2.60            1.00
# 16                     15.00                1.10            0.50
# 17                     14.60                1.14            0.50
# 18                      9.00                1.10            0.30
# 19                      8.40                0.30            0.10
# 20                     11.30                0.75            0.34
# 21                     17.00                0.80            0.44
# 22                     15.00                0.82            0.38
# 23                      8.00                0.00            0.00
# 24                      9.80                1.44            0.39
# 25                      8.30                1.00            0.20
# 26                     11.00                0.00            0.40
# 27                     22.40                2.20            0.70
# 28                      9.50                0.90            0.25
# 29                     15.00                0.40            0.10
# 30                     18.00                0.00            0.00
# 31                     13.12                0.54            0.12
# 32                      7.00                1.00            0.40
# 33                     11.40                0.70            0.28
# 34                     18.70                1.70            1.20
# 35                     12.00                1.20            0.70
# 36                      5.50                0.80            0.40
# 37                      8.30                0.00            0.40
# 38                      3.90                0.90            0.20
# 39                      8.00                0.60            0.20
#
#     nutritions.calories  nutritions.sugar
# 0                    52             10.30
# 1                    15              3.20
# 2                   160              0.66
# 3                    96             17.20
# 4                    40              4.50
# 5                    29              5.40
# 6                    50              8.00
# 7                    46              4.00
# 8                    60              8.00
# 9                   147              6.75
# 10                   44              3.00
# 11                   74             16.00
# 12                   44              0.00
# 13                   69             16.00
# 14                   21              6.40
# 15                   68              9.00
# 16                   61              9.00
# 17                   61              8.90
# 18                   29              2.50
# 19                   25              1.70
# 20                   50              5.74
# 21                   66             15.00
# 22                   60             13.70
# 23                   34              8.00
# 24                   43              8.10
# 25                   43              8.20
# 26                   43              1.00
# 27                   97             11.20
# 28                   39              8.40
# 29                   57             10.00
# 30                   81             18.00
# 31                   50              9.85
# 32                   36              3.00
# 33                   46              9.92
# 34                   83             13.70
# 35                   53              4.40
# 36                   29              5.40
# 37                   45              9.10
# 38                   74              2.60
# 39                   30              6.00

# %% [markdown]
# Let's see if we can extract some information from this dataframe. Perhaps, we need to know the family and genus of a cherry.

# %%
cherry = df2.loc[df2["name"] == 'Cherry']
(cherry.iloc[0]['family']) , (cherry.iloc[0]['genus'])
# Out:
# ('Rosaceae', 'Prunus')

# %% [markdown]
# ## Exercise 2
# In this Exercise, find out how many calories are contained in a banana.

# %%
# Write your code here
df2['nutritions.calories'][df2["name"] == 'Banana']
# Out:
# 3    96
# Name: nutritions.calories, dtype: int64

# %%
cal_banana = df2.loc[df2["name"] == 'Banana']
cal_banana.iloc[0]['nutritions.calories']
# Out:
# 96

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# cal_banana = df2.loc[df2["name"] == 'Banana']
# cal_banana.iloc[0]['nutritions.calories']
# ```
#
# </details>

# %% [markdown]
# ## Exercise 3
#
# This [page](https://github.com/public-apis/public-apis#animals) contains a list of free public APIs. Choose any API of your interest and use it to load/extract some information, as shown in the example above.
# 1. Using `requests.get("url")` function, load your data.

# %%
# Write your code here
url='https://collectionapi.metmuseum.org/public/collection/v1/objects'
met=requests.get(url)

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# data2 = requests.get("https://www.fishwatch.gov/api/species")
# ```
#
# </details>

# %% [markdown]
# 2. Retrieve results using `json.loads()` function.

# %%
# Write your code here
numbers = json.loads(met.text)['objectIDs']
met_sample=[]

for i in numbers[::100000]:
    met_sample.append(requests.get(url+'/'+ str(i)).json())

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# results2 = json.loads(data2.text)
# ```
#
# </details>

# %% [markdown]
# 3. Convert json data into *pandas* data frame.

# %%
# Write your code here
df_met = pd.json_normalize(met_sample)

# %%
# Setting this option will print all collumns of a dataframe
pd.set_option('display.max_columns', None)
# Setting this option will print all of the data in a feature
pd.set_option('display.max_colwidth', None)
df_met
# Out:
#    objectID  isHighlight   accessionNumber accessionYear  isPublicDomain  \
# 0         1        False        1979.486.1          1979           False
# 1    190243        False    07.225.510.505          1907           False
# 2    324873        False          59.41.43          1959            True
# 3    445365        False            08.246          1908            True
# 4    687590        False  63.350.307.72.40          1963           False
#
#                                                           primaryImage  \
# 0
# 1
# 2  https://images.metmuseum.org/CRDImages/an/original/DP-15116-006.jpg
# 3        https://images.metmuseum.org/CRDImages/is/original/08.246.JPG
# 4
#
#                                                       primaryImageSmall  \
# 0
# 1
# 2  https://images.metmuseum.org/CRDImages/an/web-large/DP-15116-006.jpg
# 3        https://images.metmuseum.org/CRDImages/is/web-large/08.246.JPG
# 4
#
#                                                                                                              additionalImages  \
# 0                                                                                                                          []
# 1                                                                                                                          []
# 2                                                       [https://images.metmuseum.org/CRDImages/an/original/DP-15116-052.jpg]
# 3  [https://images.metmuseum.org/CRDImages/is/original/4736.jpg, https://images.metmuseum.org/CRDImages/is/original/4736.jpg]
# 4                                                                                                                          []
#
#                                                                                                                                                                                                                             constituents  \
# 0  [{'constituentID': 164292, 'role': 'Maker', 'name': 'James Barton Longacre', 'constituentULAN_URL': 'http://vocab.getty.edu/page/ulan/500011409', 'constituentWikidata_URL': 'https://www.wikidata.org/wiki/Q3806459', 'gender': ''}]
# 1                                                                                                                                                                                                                                   None
# 2                                                                                                                                                                                                                                   None
# 3                                                                                                                                                                                                                                   None
# 4                                                                     [{'constituentID': 182109, 'role': 'Publisher', 'name': 'Issued by Mother&#39;s Cookies', 'constituentULAN_URL': '', 'constituentWikidata_URL': '', 'gender': ''}]
#
#                                department objectName  \
# 0                       The American Wing       Coin
# 1  European Sculpture and Decorative Arts      Chute
# 2                Ancient Near Eastern Art      Beads
# 3                             Islamic Art      Stele
# 4                     Drawings and Prints      Print
#
#                                                                                                         title  \
# 0                                                                                One-dollar Liberty Head Coin
# 1                                                                                       Chute (part of a set)
# 2                                                                                           Necklace of beads
# 3                                                                         Funerary Stele with Cross Medallion
# 4  No. 41, Lea Francis, bakery insert card from the Sports Cars 1955 series (D72), issued by Mother's Cookies
#
#     culture    period dynasty reign portfolio artistRole artistPrefix  \
# 0                                                  Maker
# 1
# 2  Parthian  Parthian
# 3
# 4                                              Publisher    Issued by
#
#        artistDisplayName  \
# 0  James Barton Longacre
# 1
# 2
# 3
# 4       Mother's Cookies
#
#                                                                artistDisplayBio  \
# 0  American, Delaware County, Pennsylvania 1794–1869 Philadelphia, Pennsylvania
# 1
# 2
# 3
# 4
#
#   artistSuffix         artistAlphaSort artistNationality artistBeginDate  \
# 0               Longacre, James Barton          American            1794
# 1
# 2
# 3
# 4                     Mother's Cookies          American            1914
#
#   artistEndDate artistGender                      artistWikidata_URL  \
# 0          1869               https://www.wikidata.org/wiki/Q3806459
# 1
# 2
# 3
# 4          2008
#
#                                artistULAN_URL       objectDate  \
# 0  http://vocab.getty.edu/page/ulan/500011409             1853
# 1                                                 18th century
# 2                                                  ca. 150 BCE
# 3                                              6th–7th century
# 4                                                         1955
#
#    objectBeginDate  objectEndDate                       medium  \
# 0             1853           1853                         Gold
# 1             1700           1799                  Gilt bronze
# 2             -150           -150           Stone, shell, frit
# 3              500            699   Sandstone; carved, painted
# 4             1955           1955  Commercial color lithograph
#
#                                        dimensions  \
# 0                          Dimensions unavailable
# 1                     Length: 7 3/4 in. (19.7 cm)
# 2                              0.43 in. (1.09 cm)
# 3  H. 24 3/4 in. (62.9 cm)\r\nW. 14 in. (35.6 cm)
# 4         Sheet: 3 1/2 × 2 1/2 in. (8.9 × 6.4 cm)
#
#                                                                                                               measurements  \
# 0                                                                                                                     None
# 1                     [{'elementName': 'Length', 'elementDescription': None, 'elementMeasurements': {'Length': 19.68504}}]
# 2                         [{'elementName': 'Overall', 'elementDescription': None, 'elementMeasurements': {'Depth': 1.09}}]
# 3   [{'elementName': 'Overall', 'elementDescription': None, 'elementMeasurements': {'Height': 62.8651, 'Width': 35.5601}}]
# 4  [{'elementName': 'Sheet', 'elementDescription': None, 'elementMeasurements': {'Height': 8.8900175, 'Width': 6.350013}}]
#
#                                                           creditLine  \
# 0                                 Gift of Heinz L. Stoppelmann, 1979
# 1                                   Gift of J. Pierpont Morgan, 1906
# 2                                                  Rogers Fund, 1959
# 3                                                  Rogers Fund, 1908
# 4  The Jefferson R. Burdick Collection, Gift of Jefferson R. Burdick
#
#    geographyType                     city state county country       region  \
# 0
# 1
# 2                                                               Mesopotamia
# 3  Probably from  Hermonthis (now Armant)                Egypt
# 4
#
#   subregion locale locus excavation river         classification  \
# 0
# 1                                          Metalwork-Gilt Bronze
# 2    Nippur
# 3                                                      Sculpture
# 4                                                         Prints
#
#   rightsAndReproduction linkResource              metadataDate  \
# 0                                     2021-04-06T04:41:04.967Z
# 1                                     2020-11-14T04:40:04.457Z
# 2                                     2022-11-29T04:46:33.693Z
# 3                                     2022-06-29T04:55:45.873Z
# 4                                     2020-09-16T18:35:19.457Z
#
#                                  repository  \
# 0  Metropolitan Museum of Art, New York, NY
# 1  Metropolitan Museum of Art, New York, NY
# 2  Metropolitan Museum of Art, New York, NY
# 3  Metropolitan Museum of Art, New York, NY
# 4  Metropolitan Museum of Art, New York, NY
#
#                                                 objectURL  \
# 0       https://www.metmuseum.org/art/collection/search/1
# 1  https://www.metmuseum.org/art/collection/search/190243
# 2  https://www.metmuseum.org/art/collection/search/324873
# 3  https://www.metmuseum.org/art/collection/search/445365
# 4  https://www.metmuseum.org/art/collection/search/687590
#
#                                                                                                                                   tags  \
# 0                                                                                                                                 None
# 1                                                                                                                                 None
# 2                                                                                                                                 None
# 3  [{'term': 'Cross', 'AAT_URL': 'http://vocab.getty.edu/page/aat/300235443', 'Wikidata_URL': 'https://www.wikidata.org/wiki/Q40843'}]
# 4    [{'term': 'Cars', 'AAT_URL': 'http://vocab.getty.edu/page/aat/300178739', 'Wikidata_URL': 'https://www.wikidata.org/wiki/Q1420'}]
#
#   objectWikidata_URL  isTimelineWork GalleryNumber
# 0                              False
# 1                              False
# 2                              False
# 3                              False           302
# 4                              False

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# df3 = pd.DataFrame(results2)
# df3
# ```
#
# </details>

# %% [markdown]
# # Congratulations! - You have completed the lab

# %% [markdown]
# ## Author
# [Svitlana Kramar](www.linkedin.com/in/svitlana-kramar)
#
#
# Svitlana is a master’s degree Data Science and Analytics student at University of Calgary, who enjoys travelling, learning new languages and cultures and loves spreading her passion for Data Science.

# %% [markdown]
#                                 Copyright © 2020 IBM Corporation. All rights reserved.
